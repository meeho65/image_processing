# %% [markdown]
# Task 1

# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
from datetime import datetime
from skimage.color import rgb2gray

# %%
image = cv2.imread('avatar.jpeg')
if image is None:
    print("Error: Image not loaded properly. Check the file path or format.")

# %%
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (1280, 720, 3)

# %%
image.dtype.itemsize*8*image.shape[2]
# Out:
# 24

# %%
image_path='avatar.jpeg'
file_size = os.path.getsize(image_path)

# %%
file_size
# Out:
# 95198

# %%
file_stats = os.stat(image_path)

# %%
date = file_stats.st_ctime

# %%
readable_date = datetime.fromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')

# %%
readable_date
# Out:
# '2024-09-23 11:10:05'

# %%
image_double = image.astype(np.float64)

# %%
image_double[0, 0] = -50
image_double[0, 1] = 300

# %%
image_double
# Out:
# array([[[-50., -50., -50.],
#         [300., 300., 300.],
#         [171., 183., 185.],
#         ...,
#         [168., 185., 188.],
#         [168., 185., 188.],
#         [167., 184., 187.]],
#
#        [[178., 190., 192.],
#         [175., 188., 190.],
#         [174., 186., 188.],
#         ...,
#         [165., 182., 185.],
#         [164., 181., 184.],
#         [163., 180., 183.]],
#
#        [[176., 189., 191.],
#         [172., 187., 189.],
#         [172., 185., 187.],
#         ...,
#         [162., 179., 182.],
#         [160., 177., 180.],
#         [159., 176., 179.]],
#
#        ...,
#
#        [[170., 193., 201.],
#         [171., 194., 202.],
#         [172., 195., 203.],
#         ...,
#         [186., 208., 220.],
#         [185., 207., 219.],
#         [185., 207., 219.]],
#
#        [[170., 193., 201.],
#         [170., 193., 201.],
#         [171., 194., 202.],
#         ...,
#         [188., 210., 221.],
#         [188., 210., 222.],
# ...

# %%
image_uint8 = np.clip(image_double, 0, 255).astype(np.uint8)

# %%
print(image_uint8)
# Out:
# [[[  0   0   0]
#   [255 255 255]
#   [171 183 185]
#   ...
#   [168 185 188]
#   [168 185 188]
#   [167 184 187]]
#
#  [[178 190 192]
#   [175 188 190]
#   [174 186 188]
#   ...
#   [165 182 185]
#   [164 181 184]
#   [163 180 183]]
#
#  [[176 189 191]
#   [172 187 189]
#   [172 185 187]
#   ...
#   [162 179 182]
#   [160 177 180]
#   [159 176 179]]
#
#  ...
#
#  [[170 193 201]
#   [171 194 202]
#   [172 195 203]
#   ...
#   [186 208 220]
#   [185 207 219]
#   [185 207 219]]
#
#  [[170 193 201]
#   [170 193 201]
#   [171 194 202]
#   ...
#   [188 210 221]
#   [188 210 222]
#   [187 209 221]]
#
#  [[170 193 201]
#   [170 193 201]
#   [171 194 202]
#   ...
#   [189 211 222]
#   [189 211 223]
#   [189 211 223]]]

# %%
cv2.imshow('Converted Image', image_uint8)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Task 2

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
 rubish,binarized_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# %%
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(binarized_image, cmap='gray')
plt.title('Binarized Image')

plt.show()

# %% [markdown]
# Task 3

# %%
image2 = cv2.imread('pic2.jpeg')

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
cv2.imshow('Image', image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = rgb2gray(image2);

# %%
cv2.imshow('Image', gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
height, width, channels = image2.shape

# %%
print(f"Image size: {width}x{height}")
print(f"Number of channels: {channels}")
# Out:
# Image size: 720x1280
# Number of channels: 3

# %%
    if channels == 3:
        print("This is a three-channel image (RGB).")
        gray_image = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
        _, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

        cv2.imshow("Original Image", image2)
        cv2.imshow("Grayscale Image", gray_image)
        cv2.imshow("Binary Image", binary_image)
    
    elif channels == 1:
        print("This is a one-channel image (Grayscale).")
        cv2.imshow("Grayscale Image", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# This is a three-channel image (RGB).

# %% [markdown]
# TASK 4

# %%
def binarize_image(image, threshold=127):
    height, width = image.shape 
    binary_image = np.zeros((height, width), dtype=np.uint8)
    for i in range(height):
        for j in range(width):
            if image[i, j] > threshold:
                binary_image[i, j] = 255
            else:
                binary_image[i, j] = 0

    return binary_image

# %%
gray_image = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# %%
binary_image = binarize_image(gray_image, threshold=127)

# %%
cv2.imshow("Binary Image", binary_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# TASK 5

# %%
cap = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = cap.read()
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Grayscale Video', gray_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
